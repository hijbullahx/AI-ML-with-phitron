# %% [markdown]
# # 1.1 Introduction to the Course

# %% [markdown]
# # 1.2 Why Deep Learning?

# %% [markdown]
# # 1.3 Use Case of Deep Learning

# %% [markdown]
# # 1.4 Difference Between Machine Learning and Deep Learning

# %% [markdown]
# # 1.5 How Machine Learning Fails

# %% [markdown]
# # 1.6 How a Biological Neuron Works

# %% [markdown]
# # 1.7 Introduction to Artificial Neurons
