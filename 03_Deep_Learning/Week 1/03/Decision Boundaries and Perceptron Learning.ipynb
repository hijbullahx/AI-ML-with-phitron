# %% [markdown]
# # 3.1 Introduction

# %% [markdown]
# # 3.2 Types of Deep Learning

# %% [markdown]
# # 3.3 Decision Boundary and Bias Visualization

# %% [markdown]
# # 3.4 Perceptron Learning Rule Part 1

# %% [markdown]
# # 3.5 Perceptron Learning Rule Part 2

# %% [markdown]
# # 3.6 Perceptron Learning Rule Part 3

# %% [markdown]
# # 3.7 TensorFlow Playground
