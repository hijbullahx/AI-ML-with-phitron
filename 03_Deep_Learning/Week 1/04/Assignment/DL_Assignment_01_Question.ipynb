# %% [markdown]
# # DL Assignment 01
#
# **Name:** **Md. Taher Bin Omar Hijbullah**
#
# **Course Email:**  **22303142**
#
# This is a small assignment that connects topics from Module 1, 2, and 3.
#
# ## End of Assignment
#
# Before submitting:
# - Run all cells from top to bottom.
# - Check that all answer sections are filled.
# - Instruction video অনুযায়ী আমাদের দেয়া Colab ফাইলটি থেকে প্রথম একটি Save copy in drive করে নিবা। এরপর Google colab এর মধ্যে কোডগুলো করবে এবং সেই ফাইলটি ‘Anyone with the link’ & ‘View’ Access দিয়ে ফাইলটির Shareble Link টি সাবমিট করবে।

# %% [markdown]
# # Question 01: [ Marks 10 ]
#
# What is a perceptron?
# Explain its three main components and their roles.

# %% [markdown]
# **Write** Answer 01:
#
# Perceptron:  A simple model for binary classification.
#
# Components
#
# -Weights: importance of inputs
# -Bias: shifts decision boundary
# -Activation: decides output (0/1)

# %% [markdown]
# # Question 02: [ Marks 10 ]
#
# What is a decision boundary in a perceptron?
# Explain how the equation
# w₁x₁ + w₂x₂ + b = 0
# represents a decision boundary geometrically.

# %% [markdown]
# ## Write Answer 02:
# A decision boundary in a perceptron is the line that seperates one class from another.
#
# The equation represents a line in the x1, x2 plane. if w1x1+w2x2 > 0 classified as one class(assume binary 1), then while the equation is < 0 it will be classified as 0.

# %% [markdown]
# # Question 03: [ Marks 15 ]
#
# Why is the perceptron called a linear classifier?
# Explain your answer using the concept of linear separability and logical gate examples such as AND, OR, and XOR.

# %% [markdown]
# ## Write Answer 03:
# A perceptron is called a linear classifier because it separates data using a straight line, the concept of lenear separability is that classes can be divided by a single straight line. And the perceptron learns weights and bias to form this line.
#
# Logical Gates:
#
# -AND : line separates (1,1) from the rest, so it is linearly seperable.
#
# -OR: Line separetes (0,0) from the rest, so it is alos linearly seperable.
#
# -XOR: Can not seperate with one straingt line, so not linearly separable.

# %% [markdown]
# # Question 04: [ Marks 15 ]
#
# Write the perceptron weight update rule and explain it intuitively.
# Why are the weights updated only when the prediction is incorrect?

# %% [markdown]
# ## Write Answer 04:
#
# Rules:
#
# W(new) = W(old) + eta.(y-Y(bar)).x
#
# b(new) = b(old) + eta.(y-t(bar))
#
# Here,
# W = weights,
# b = bias,
# eta = learning rate,
# y = true label,
# y(bar) = predicted output,
# x = input vector
#
# And, if prediction is correct: error((y-Y(bar))) = 0, so no update. elif prediction is wrong , erro ((y-Y(bar))) is not = 0, so weights shift slightly toward the correct answer.
#
# This process ensures the perceptron learns only from mistakes, gradualy adjusting the decision boundary to classufy inputs correctly.

# %% [markdown]
# # Question 05: [ Marks 10 ]
#
# Why does a single-layer perceptron fail to solve the XOR problem?
# What does this limitation tell us about the need for multilayer neural networks?

# %% [markdown]
# ## Write Answer 05:
#
# A single-layer perceptron fails on XOR because XOR is not linearly separable, no straight line can split the outputs correctly.
#
# -AND/OR: Spearable by one line
# -XOR: needs curved/ non-linear boundary.
#
# These tells why we need multilayer neural networks, they combine perceptrons to form complex, non-liner decision boundaris.
#
# So, XOR proves the limit of linear classifiers, motivates multilayer networks.

# %% [markdown]
# # Question 06: [ Marks 20 ]
#
# What is meant by the “perceptron Learning Rule” or weight adjustment method?
# Why can adjusting one weight affect the classification of other points?

# %% [markdown]
# ## Write Answer 06:
#
# The learning rule (weight adjument method) updates weights to reduce classification wrros.
#
# -If prediction is correct, then no change.
#
# -Elif prediction is wrong, weight shift toward the correct class.
#
# -This gradually moves the decision boundary to classify inputs correctly.
#
# -The perceptron's decision boundary depends on all weights together, changing even one weight rotates or shifts the boundary line. That shift can fix the misclassified point vut also change how other points are classified.
#
# So, weights are linked through the boundary equation, updating one wirht changes the whole boundary, affecting all points.

# %% [markdown]
# # Question 07: [ Marks 20 ]
#
# What are the main limitations of a single-layer perceptron?
# How does the idea of using more than one layer (MLP) help overcome these limitations at a high level accoriding to you?

# %% [markdown]
# ## Write Answer 07:
#
# Single-layer perceptron limitaions:
#
# -Only habdles linear separable problems.
#
# -Fails on non-linear tasks (e.g., XOR).
#
# -Limited to simple boundaries.
#
# MLP Advantages:
#
# -Adds hidden layers and non-linear activations.
#
# -Builds complex, curved boundaries.
#
# -Solves non-linear problems so more powerful.
