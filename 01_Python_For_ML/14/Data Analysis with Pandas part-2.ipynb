# %% [markdown]
# # 14.1 Filtering Based on String

# %%
import pandas as pd

emp_data = {
    'Name': [
        'Niloy', 'Ishrat', 'Pavel', 'Tuhin', 'Sadia', 'Morshed', 'Labiba', 'Harun'
    ],
    'City': [
        'Dhaka', 'new Chittagong', 'Khulna', 'Rajshahi', 'Sylhet', 'Barisal', 'Comilla', 'Mymensingh'
    ],
    'Department': [
        'HR', 'IT', 'Finance', 'Sales', 'Marketing', 'Support', 'Admin', 'IT'
    ],
    'Salary': [
        54000, 62000, 50000, 48000, 56000, 51000, 53000, 60000
    ]
}

df = pd.DataFrame(emp_data)
print(df)
# Out:
#       Name            City Department  Salary
# 0    Niloy           Dhaka         HR   54000
# 1   Ishrat  new Chittagong         IT   62000
# 2    Pavel          Khulna    Finance   50000
# 3    Tuhin        Rajshahi      Sales   48000
# 4    Sadia          Sylhet  Marketing   56000
# 5  Morshed         Barisal    Support   51000
# 6   Labiba         Comilla      Admin   53000
# 7    Harun      Mymensingh         IT   60000

# %%
#filtering city name with n
df.loc[df['City'].str.contains("N", case = False)]
# Out:
#      Name            City Department  Salary
# 1  Ishrat  new Chittagong         IT   62000
# 2   Pavel          Khulna    Finance   50000
# 7   Harun      Mymensingh         IT   60000

# %%
#filtering starts with new
df.loc[df['City'].str.contains(r"^new")]
# Out:
#      Name            City Department  Salary
# 1  Ishrat  new Chittagong         IT   62000

# %%
#Ends with a
df.loc[df['City'].str.contains(r"a$")]
# Out:
#      Name     City Department  Salary
# 0   Niloy    Dhaka         HR   54000
# 2   Pavel   Khulna    Finance   50000
# 6  Labiba  Comilla      Admin   53000

# %%
# name starts with a vowel
df.loc[df['Name'].str.contains(r"^[AEIOU]", case = False)]
# Out:
#      Name            City Department  Salary
# 1  Ishrat  new Chittagong         IT   62000

# %%
#City contains c | d
df.loc[df['City'].str.contains(r"c|d", case = False)]
# Out:
#      Name            City Department  Salary
# 0   Niloy           Dhaka         HR   54000
# 1  Ishrat  new Chittagong         IT   62000
# 6  Labiba         Comilla      Admin   53000

# %% [markdown]
# # 14.2 Adding new Column and Saving the File

# %%
df = pd.read_csv('student_marks.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Adding a column with a constant value
df['Country'] = 'Bangladesh'
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df['Total marks'] = df['Data Structure Marks'] + df['Algorithm Marks'] + df['Python Marks']
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Condition, A+ in DS
import numpy as np
df['A+ in DS'] = np.where(df['Data Structure Marks']>90, 'A+', 'A')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#if pass in DS
df['Passed in DS'] = df['Data Structure Marks'] > 70
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#First name in separate column
df["First Name"] = df['FullName'].str.split(' ').str[0]
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df1 = pd.read_csv('student_marks.csv')
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Saving internally
df.to_csv('new_data.csv')

# %% [markdown]
# # 14.3 Checking Duplicates and Null Values in DF

# %%
import pandas as pd

data = {
  "Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
  "City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
  "Score": [85, 90, 78, 85, 95, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     85
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
# Check if names are unique or not
print(df['Name'].unique())

len(df['Name'].unique())
# Out:
# ['Alice' 'Bob' 'Charlie' 'David']
# 4

# %%
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Unique data structure marks
print(df1['Data Structure Marks'].unique())
print(len(df1['Data Structure Marks'].unique()))
print(df1['Data Structure Marks'].nunique()) #Counts without null
#unique works for series only
# Out:
# [85. 92. 88. 78. nan 75. 80. 81. 72. 89. 86. 94. 90.]
# 13
# 12

# %%
#nuniques works for entire df
df1.nunique()
# Out:
# StudentID               20
# FullName                20
# Data Structure Marks    12
# Algorithm Marks         12
# Python Marks            12
# CompletionStatus         3
# EnrollmentDate          20
# Instructor               3
# Location                 5
# dtype: int64

# %%
#Checking null
df1.isnull()
# Out:
#     StudentID  FullName  Data Structure Marks  Algorithm Marks  Python Marks  \
# 0       False     False                 False            False         False
# 1       False     False                 False            False          True
# 2       False     False                 False            False         False
# 3       False     False                 False            False         False
# 4       False     False                  True             True         False
# 5       False     False                 False            False         False
# 6       False     False                 False            False          True
# 7       False     False                 False            False         False
# 8       False     False                 False            False         False
# 9       False     False                 False            False         False
# 10      False     False                  True             True         False
# ...

# %%
df1['Data Structure Marks'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20     True
# Name: Data Structure Marks, dtype: bool

# %%
df1['Data Structure Marks'].notnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10    False
# 11     True
# 12     True
# 13    False
# 14     True
# 15     True
# 16     True
# 17     True
# 18    False
# 19     True
# 20    False
# Name: Data Structure Marks, dtype: bool

# %%
#Check if the column has null value
df1['Data Structure Marks'].hasnans
# Out:
# True

# %%
df1['StudentID'].hasnans
# Out:
# True

# %% [markdown]
# # 14.4 Handling Duplicates Values

# %%
import pandas as pd

data = {
  "Name": ["Alice", "Bob", "Charlie", "Alice", "David", "Bob"],
  "City": ["New York", "London", "Paris", "New York", "Tokyo", "London"],
  "Score": [85, 90, 78, 70, 95, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
#check if duplicated
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
#Deketing duplicate
df.drop_duplicates()
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95
# 5      Bob    London     90

# %%
#permanent delete

df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %%
#duplicate name based delete
df.drop_duplicates(subset=['Name'])
# Out:
#       Name      City  Score
# 0    Alice  New York     85
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 4    David     Tokyo     95

# %%
#cities
df.drop_duplicates(subset=['City'], keep = 'last')
# Out:
#       Name      City  Score
# 1      Bob    London     90
# 2  Charlie     Paris     78
# 3    Alice  New York     70
# 4    David     Tokyo     95

# %% [markdown]
# # 14.5 Handling Null Values

# %%
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Delete full row if any null exist
df1.dropna()
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
#Delete a row if all are null
df1.dropna(how='all', inplace=True)
df1
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
# Conditional
df1.dropna(subset=['Python Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# ...

# %%
df1.dropna(subset=['Python Marks','Algorithm Marks'])
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# 16    PH1017       Afsana Mimi                  90.0             90.0
# 17    PH1018       Babul Ahmed                  88.0             88.0
# ...

# %%
df1.fillna(0)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   0.0              0.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   0.0              0.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df = pd.read_csv('student_marks.csv')
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Change null
df.fillna(0)
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   0.0              0.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   0.0              0.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Works with string
df['FullName'].fillna('unknown')
# Out:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# 20             unknown
# Name: FullName, dtype: object

# %%
df['Python Marks'].fillna(df['Python Marks'].mean(),inplace = True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19472\1382189917.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Python Marks'].fillna(df['Python Marks'].mean(),inplace = True)
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# ...

# %% [markdown]
# # 14.6 Statistical Functions in Pandas

# %%
df.dropna()
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# 12    PH1013      Tanvir Ahmed                  75.0             75.0
# 14    PH1015      Wahiduzzaman                  86.0             86.0
# ...

# %%
#Summetion
df['Data Structure Marks'].sum()
# Out:
# np.float64(1344.0)

# %%
#Max and Min
print(df['Data Structure Marks'].min())
print(df['Data Structure Marks'].max())
# Out:
# 72.0
# 94.0

# %%
#Mean -> Average
df['Data Structure Marks'].mean()
# Out:
# np.float64(84.0)

# %%
#Median 
df['Data Structure Marks'].median()
# Out:
# np.float64(85.5)

# %%
#mode-> Heighest frequency numbers
df['Data Structure Marks'].mode()
# Out:
# 0    75.0
# 1    85.0
# 2    86.0
# 3    88.0
# Name: Data Structure Marks, dtype: float64

# %%
#Standard Deviation
df['Data Structure Marks'].std()
# Out:
# np.float64(6.501281924871945)

# %%
#Co-relation metrix
df[['Data Structure Marks', 'Python Marks']].corr()
# Out:
#                       Data Structure Marks  Python Marks
# Data Structure Marks              1.000000      0.776845
# Python Marks                      0.776845      1.000000

# %%
#Sum in different columns
df[['Data Structure Marks', 'Python Marks']].sum()
# Out:
# Data Structure Marks    1344.0
# Python Marks            1799.0
# dtype: float64

# %%
#Sum in different columns row wise
df[['Data Structure Marks', 'Python Marks']].sum(axis=1)
# Out:
# 0     173.000000
# 1     177.666667
# 2     173.000000
# 3     160.000000
# 4      95.000000
# 5     153.000000
# 6     165.666667
# 7     166.000000
# 8     148.000000
# 9     177.000000
# 10     91.000000
# 11    172.000000
# 12    154.000000
# 13     85.666667
# 14    170.000000
# 15    179.666667
# 16    183.000000
# 17    173.000000
# 18     85.666667
# 19    175.000000
# 20     85.666667
# dtype: float64

# %%
#Do sum and keep in a column
df['Total Marks'] = df.iloc[::, 2:5].sum(axis=1)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
df.describe()
# Out:
#        Data Structure Marks  Algorithm Marks  Python Marks  Total Marks
# count             16.000000        16.000000     21.000000    21.000000
# mean              84.000000        84.000000     85.666667   213.666667
# std                6.501282         6.501282      4.512944    73.089215
# min               72.000000        72.000000     76.000000    85.666667
# 25%               79.500000        79.500000     85.000000   220.000000
# 50%               85.500000        85.500000     85.666667   247.000000
# 75%               88.250000        88.250000     88.000000   261.000000
# max               94.000000        94.000000     95.000000   273.666667

# %% [markdown]
# # 14.7 Apply Function in DF

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Min max scalling, scalled = (x-min)/(max-min)
mn = df['Total Marks'].min()
mx = df['Total Marks'].max()

df['Scaled Marks'] = df['Total Marks'].apply(lambda x : (x-mn)/(mx-mn))

# %%
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
#Custom build fuction
def grading_system(marks):
  if marks >=260:
    return 'A+'
  elif marks >= 250:
    return 'A'
  else:

    return 'A-' 

df['Grade']  = df['Total Marks'].apply(grading_system)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %%
def marking_system(df):
  a = df['Data Structure Marks'] * 2
  b = df['Python Marks'] * 3
  c = df['Algorithm Marks'] * 4

  return a+b+c


df['Exceptional Marks'] = df.apply(marking_system,axis=1)
df
# Out:
#    StudentID          FullName  Data Structure Marks  Algorithm Marks  \
# 0     PH1001       Alif Rahman                  85.0             85.0
# 1     PH1002     Fatima Akhter                  92.0             92.0
# 2     PH1003     Imran Hossain                  88.0             88.0
# 3     PH1004  Jannatul Ferdous                  78.0             78.0
# 4     PH1005       Kamal Uddin                   NaN              NaN
# 5     PH1006       Laila Begum                  75.0             75.0
# 6     PH1007    Mahmudul Hasan                  80.0             80.0
# 7     PH1008       Nadia Islam                  81.0             81.0
# 8     PH1009        Omar Faruq                  72.0             72.0
# 9     PH1010      Priya Sharma                  89.0             89.0
# 10    PH1011      Rahim Sheikh                   NaN              NaN
# 11    PH1012   Sadia Chowdhury                  85.0             85.0
# ...

# %% [markdown]
# # 14.8 DateTime and Timedelta

# %%
df = pd.read_csv('student_data.csv')
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df['EnrollmentDate']
# Out:
# 0     2024-09-01
# 1     2024-08-11
# 2     2024-05-08
# 3     2024-07-05
# 4     2024-02-01
# 5     2024-09-07
# 6     2024-06-07
# 7     2024-03-22
# 8     2024-02-12
# 9     2024-06-19
# 10    2024-03-14
# 11    2024-08-04
# 12    2024-06-07
# 13    2024-01-04
# 14    2024-02-22
# 15    2024-03-23
# 16    2024-01-18
# 17    2024-06-23
# 18    2024-04-19
# 19    2024-07-21
# Name: EnrollmentDate, dtype: object

# %%
df['EnrollmentDate'] = pd.to_datetime(df['EnrollmentDate'])
df['EnrollmentDate']
# Out:
# 0    2024-09-01
# 1    2024-08-11
# 2    2024-05-08
# 3    2024-07-05
# 4    2024-02-01
# 5    2024-09-07
# 6    2024-06-07
# 7    2024-03-22
# 8    2024-02-12
# 9    2024-06-19
# 10   2024-03-14
# 11   2024-08-04
# 12   2024-06-07
# 13   2024-01-04
# 14   2024-02-22
# 15   2024-03-23
# 16   2024-01-18
# 17   2024-06-23
# 18   2024-04-19
# 19   2024-07-21
# Name: EnrollmentDate, dtype: datetime64[ns]

# %%
#Getting yeat column
df['Enrollment Year'] = df['EnrollmentDate'].dt.year
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
df['Enrollment Date'] = df['EnrollmentDate'].dt.day
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %%
#Time Delta
df['FinishedDate'] = pd.to_datetime(df['FinishedDate'])
df['Total TIme Taken'] = df['FinishedDate'] - df['EnrollmentDate']
df
# Out:
#    StudentID          FullName CompletionStatus EnrollmentDate FinishedDate  \
# 0     PH0001       Alif Rahman        Completed     2024-09-01   2024-12-23
# 1     PH0002     Fatima Akhter        Completed     2024-08-11   2024-11-07
# 2     PH0003     Imran Hossain        Completed     2024-05-08   2024-08-08
# 3     PH0004  Jannatul Ferdous        Completed     2024-07-05   2024-09-23
# 4     PH0005       Kamal Uddin        Completed     2024-02-01   2024-04-17
# 5     PH0006       Laila Begum        Completed     2024-09-07   2024-12-31
# 6     PH0007    Mahmudul Hasan        Completed     2024-06-07   2024-07-20
# 7     PH0008       Nadia Islam        Completed     2024-03-22   2024-05-01
# 8     PH0009        Omar Faruq        Completed     2024-02-12   2024-06-08
# 9     PH0010      Priya Sharma        Completed     2024-06-19   2024-08-19
# 10    PH0011      Rahim Sheikh        Completed     2024-03-14   2024-06-11
# ...

# %% [markdown]
# # 14.9 Groupby in DF.

# %%
grp = df.groupby('Instructor')

# %%
df.drop(columns= ['EnrollmentDate', 'FinishedDate'], inplace=True)

# %%
grp.sum()
# Out:
#                                                     StudentID  \
# Instructor
# Mr. David   PH0005PH0006PH0007PH0010PH0013PH0014PH0015PH00...
# Mr. Karim          PH0002PH0004PH0009PH0011PH0012PH0019PH0020
# Ms. Salma                            PH0001PH0003PH0008PH0016
#
#                                                      FullName  \
# Instructor
# Mr. David   Kamal UddinLaila BegumMahmudul HasanPriya Shar...
# Mr. Karim   Fatima AkhterJannatul FerdousOmar FaruqRahim S...
# Ms. Salma     Alif RahmanImran HossainNadia IslamZiaur Rahman
#
#                                              CompletionStatus  \
# Instructor
# Mr. David   CompletedCompletedCompletedCompletedCompletedC...
# Mr. Karim   CompletedCompletedCompletedCompletedCompletedC...
# Ms. Salma                CompletedCompletedCompletedCompleted
#
#                                                      Location  Total Marks  \
# Instructor
# Mr. David   SylhetKhulnaChattogramDhakaDhakaSylhetRajshahi...         2399
# ...

# %%
df.drop(columns= ['StudentID', 'FullName', 'CompletionStatus'], inplace=True)

# %%
grp = df.groupby('Instructor')
grp.sum()
# Out:
#                                                      Location  Total Marks  \
# Instructor
# Mr. David   SylhetKhulnaChattogramDhakaDhakaSylhetRajshahi...         2399
# Mr. Karim            DhakaKhulnaDhakaSylhetSylhetSylhetKhulna         1911
# Ms. Salma                           KhulnaDhakaKhulnaRajshahi         1049
#
#             Enrollment Year  Enrollment Date Total TIme Taken
# Instructor
# Mr. David             18216              108         662 days
# Mr. Karim             14168               86         658 days
# Ms. Salma              8096               54         335 days

# %%
grp.min()
# Out:
#               Location  Total Marks  Enrollment Year  Enrollment Date  \
# Instructor
# Mr. David   Chattogram          236             2024                1
# Mr. Karim        Dhaka          253             2024                4
# Ms. Salma        Dhaka          234             2024                1
#
#            Total TIme Taken
# Instructor
# Mr. David           43 days
# Mr. Karim           80 days
# Ms. Salma           40 days

# %%
grp.max()
# Out:
#             Location  Total Marks  Enrollment Year  Enrollment Date  \
# Instructor
# Mr. David     Sylhet          291             2024               23
# Mr. Karim     Sylhet          291             2024               21
# Ms. Salma   Rajshahi          300             2024               23
#
#            Total TIme Taken
# Instructor
# Mr. David          115 days
# Mr. Karim          120 days
# Ms. Salma          113 days

# %%
grp.first()
# Out:
#            Location  Total Marks  Enrollment Year  Enrollment Date  \
# Instructor
# Mr. David    Sylhet          254             2024                1
# Mr. Karim     Dhaka          271             2024               11
# Ms. Salma    Khulna          300             2024                1
#
#            Total TIme Taken
# Instructor
# Mr. David           76 days
# Mr. Karim           88 days
# Ms. Salma          113 days

# %%
grp.last()
# Out:
#             Location  Total Marks  Enrollment Year  Enrollment Date  \
# Instructor
# Mr. David      Dhaka          278             2024               23
# Mr. Karim     Khulna          253             2024               21
# Ms. Salma   Rajshahi          234             2024               23
#
#            Total TIme Taken
# Instructor
# Mr. David           89 days
# Mr. Karim           82 days
# Ms. Salma           90 days

# %%
#Boolean Mask
mask = df['Total Marks'] > 250
print(mask)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8      True
# 9      True
# 10     True
# 11     True
# 12    False
# 13     True
# 14     True
# 15    False
# 16    False
# 17     True
# 18     True
# 19     True
# Name: Total Marks, dtype: bool

# %%
#Count with boolean mask
count_above_50 = (df['Total Marks'] > 250).sum()
print(count_above_50)
# Out:
# 15

# %%
#Top Five students of every instructor
top_5 = df.sort_values('Total Marks', ascending=False).groupby('Instructor').head(5)
top_5
# Out:
#    Instructor  Location  Total Marks  Enrollment Year  Enrollment Date  \
# 0   Ms. Salma    Khulna          300             2024                1
# 8   Mr. Karim     Dhaka          291             2024               12
# 14  Mr. David  Rajshahi          291             2024               22
# 9   Mr. David     Dhaka          286             2024               19
# 13  Mr. David    Sylhet          285             2024                4
# 10  Mr. Karim    Sylhet          283             2024               14
# 17  Mr. David     Dhaka          278             2024               23
# 18  Mr. Karim    Sylhet          277             2024               19
# 5   Mr. David    Khulna          272             2024                7
# 1   Mr. Karim     Dhaka          271             2024               11
# 3   Mr. Karim    Khulna          270             2024                5
# 2   Ms. Salma     Dhaka          269             2024                8
# ...

# %% [markdown]
# # 14.10 Problem Solving-1

# %% [markdown]
# ### 1. https://leetcode.com/problems/delete-duplicate-emails/

# %%
import pandas as pd

def delete_duplicate_emails(person: pd.DataFrame) -> None:
    person.sort_values('id', inplace = True)
    person.drop_duplicates(subset = ['email'], inplace = True)

# %% [markdown]
# # 14.11 Problem Solving-2

# %% [markdown]
# ### 2. https://leetcode.com/problems/count-salary-categories

# %%
import pandas as pd

def count_salary_categories(accounts: pd.DataFrame) -> pd.DataFrame:
  low_sal = (accounts['income'] <= 20000).sum()
  avg_sal = ((accounts['income']>=2000) & (accounts['income']<=50000).sum)
  high_sal = (accounts['income'] > 50000).sum()

  data = [('Low Salary',low_sal), ('Average Salary', avg_sal), ('High Salary', high_sal)]

  df = pd.DataFrame(data,columns=['Category', 'accounts_count'])

  return df

# %% [markdown]
# # Quize, practice

# %% [markdown]
# https://www.codechef.com/learn/course/pandas/LPDP06/problems/LPDPR29
# https://www.codechef.com/learn/course/pandas/LPDP06/problems/LPDPR28
# https://www.codechef.com/learn/course/pandas/LPD10/problems/LPDPR46

# %% [markdown]
# ## Due
